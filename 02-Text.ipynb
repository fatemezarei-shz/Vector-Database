# %%
import lancedb

# %%
uri = "c:/data/new1"

# %%
db = lancedb.connect(uri)

# %%
data = [
    { "vector":[1], "text": "rebel spaceships striking from a hidden base"},
    { "vector":[2],"text": "have won their first victory against the evil Galactic Empire"},
    {"vector":[3], "text": "during the battle rebel spies managed to steal secret plans"},
    { "vector":[4],"text": "to the Empire's ultimate weapon the Death Star"}
]

# %%
tbl = db.create_table("Table3", data = data)

# %%
tbl.create_fts_index("text", replace = True)

# %%
results = tbl.search('text == rebel' ).limit(2).to_pandas()

# %%
results
# Out:
#   vector                                               text    _score
# 0    [1]       rebel spaceships striking from a hidden base  0.736170
# 1    [3]  during the battle rebel spies managed to steal...  0.654875

# %%
data2 = [
    { "vector":[1], "text": "علی به مدرسه می رود."},
    { "vector":[2],"text": "اطاعت از قانون ضروری است"},
    {"vector":[3], "text": "نیک آموز محیطی برای یادگیری حرفه ای برنامه نویسی و علم داده است"},
    { "vector":[4],"text": "علم داده بشدت در حال رشد است."}
]

# %%
tbl = db.create_table("Table4", data = data2)

# %%
 tbl.search('text == قانون').to_pandas()
# Out:
#   vector                      text    _score
# 0    [2]  اطاعت از قانون ضروری است  1.394074

# %%
tbl.create_fts_index("text")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 tbl.create_fts_index("text")
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\lancedb\table.py:2295, in LanceTable.create_fts_index(self, field_names, ordering_field_names, replace, writer_heap_size, use_tantivy, tokenizer_name, with_position, base_tokenizer, language, max_token_length, lower_case, stem, remove_stop_words, ascii_folding, ngram_min_length, ngram_max_length, prefix_only, name)
#    2292         if exist:
#    2293             fs.delete_dir(path)
# -> 2295     LOOP.run(
#    2296         self._table.create_index(
#    2297             field_names,
#    2298             replace=replace,
#    2299             config=config,
#    2300             name=name,
#    2301         )
#    2302     )
#    2303     return
#    2305 from .fts import create_index, populate_index
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\lancedb\background_loop.py:25, in BackgroundEventLoop.run(self, future)
#      24 def run(self, future):
# ---> 25     return asyncio.run_coroutine_threadsafe(future, self.loop).result()
#
# File ~\AppData\Local\anaconda3\Lib\concurrent\futures\_base.py:456, in Future.result(self, timeout)
#     454     raise CancelledError()
#     455 elif self._state == FINISHED:
# --> 456     return self.__get_result()
#     457 else:
#     458     raise TimeoutError()
#
# File ~\AppData\Local\anaconda3\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception is not None:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\lancedb\table.py:3534, in AsyncTable.create_index(self, column, replace, config, wait_timeout, name, train)
#    3529         raise TypeError(
#    3530             "config must be an instance of IvfSq, IvfPq, IvfRq, HnswPq, HnswSq,"
#    3531             " BTree, Bitmap, LabelList, or FTS, but got " + str(type(config))
#    3532         )
#    3533 try:
# -> 3534     await self._inner.create_index(
#    3535         column,
#    3536         index=config,
#    3537         replace=replace,
#    3538         wait_timeout=wait_timeout,
#    3539         name=name,
#    3540         train=train,
#    3541     )
#    3542 except ValueError as e:
#    3543     if "not support the requested language" in str(e):
#
# RuntimeError: lance error: LanceError(Index): Index name 'text_idx already exists, please specify a different name or use replace=True, C:\Users\runneradmin\.cargo\registry\src\index.crates.io-1949cf8c6b5b557f\lance-1.0.1\src\index\create.rs:134:31
