# %%
pip install hazm
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#    ---------------------------------------- 0.0/886.6 kB ? eta -:--:--
#    ----------- ---------------------------- 262.1/886.6 kB ? eta -:--:--
#    ---------------------------------------- 886.6/886.6 kB 4.9 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/24.4 MB ? eta -:--:--
#     --------------------------------------- 0.5/24.4 MB 3.3 MB/s eta 0:00:08
#    -- ------------------------------------- 1.3/24.4 MB 3.5 MB/s eta 0:00:07
#    ---- ----------------------------------- 2.9/24.4 MB 5.1 MB/s eta 0:00:05
#    ------- -------------------------------- 4.7/24.4 MB 6.2 MB/s eta 0:00:04
# ...

# %%
from hazm import *

# %%
normalizer = Normalizer()

# %%
 normalizer.normalize('الا یا ایها الساقی .....              ')
# Out:
# 'الا یا ایها الساقی …..'

# %%
sent_tokenize("علی هر روز به مدرسه می رود. وی با دوچرخه به مدرسه می رود.")
# Out:
# ['علی هر روز به مدرسه می رود.', 'وی با دوچرخه به مدرسه می رود.']

# %%
word_tokenize("علی هر روز به مدرسه می رود. وی با دوچرخه به مدرسه می رود.")
# Out:
# ['علی',
#  'هر',
#  'روز',
#  'به',
#  'مدرسه',
#  'می',
#  'رود',
#  '.',
#  'وی',
#  'با',
#  'دوچرخه',
#  'به',
#  'مدرسه',
#  'می',
#  'رود',
#  '.']

# %%
stemmer = Stemmer()

# %%
stemmer.stem('کتاب‌ها')
# Out:
# 'کتاب'

# %%
stemmer.stem('مدادها')
# Out:
# 'مداد'

# %%
stemmer.stem('اربابان')
# Out:
# 'ارباب'

# %%
stemmer.stem('درخت ها')
# Out:
# 'درخت '

# %%
stemmer.stem('ماهان')
# Out:
# 'ماه'

# %%
lemmatizer = Lemmatizer()

# %%
lemmatizer.lemmatize('می‌روم')
# Out:
# 'رفت#رو'

# %%
lemmatizer.lemmatize('نخواهم رفت')
# Out:
# 'رفت#رو'

# %%
lemmatizer.lemmatize('ندیده بودی')
# Out:
# 'دید#بین'

# %%
lemmatizer.lemmatize('گفته شده است')
# Out:
# 'گفت#گو'

# %%
normalizer.correct_spacing("وایسا        دنیا     ")
# Out:
# 'وایسا دنیا'

# %%
normalizer.correct_spacing("جمعهها که کار نمی کنم مطالعه می کنم")
# Out:
# 'جمعه\u200cها که کار نمی\u200cکنم مطالعه می\u200cکنم'

# %%
normalizer.remove_diacritics('حَذفِ اِعراب')
# Out:
# 'حذف اعراب'

# %%
normalizer.remove_specials_chars('پیامبر اکرم ﷺ')
# Out:
# 'پیامبر اکرم '

# %%
normalizer.normalize('پیامبر اکرم ﷺ')
# Out:
# 'پیامبر اکرم '

# %%
normalizer.persian_style('10.450')
# Out:
# '10٫450'

# %%
normalizer.persian_number('5 درصد')
# Out:
# '۵ درصد'

# %%
normalizer.seperate_mi('نمیدانم چه میگفت')
# Out:
# 'نمی\u200cدانم چه می\u200cگفت'

# %%
normalizer = InformalNormalizer()

# %%
normalizer.normalized_word('میرم')
# Out:
# ['می\u200cروم', 'می\u200cرم']

# %%
normalizer.normalized_word('میرم')
# Out:
# ['می\u200cروم', 'می\u200cرم']

# %%
conj = Conjugation()

# %%
conj.perfective_past('گفت')
# Out:
# ['گفتم', 'گفتی', 'گفت', 'گفتیم', 'گفتید', 'گفتند']

# %%
conj.perfective_past('دید')
# Out:
# ['دیدم', 'دیدی', 'دید', 'دیدیم', 'دیدید', 'دیدند']

# %%
conj.negative_perfective_past('دید')
# Out:
# ['ندیدم', 'ندیدی', 'ندید', 'ندیدیم', 'ندیدید', 'ندیدند']

# %%
conj.passive_perfective_past('دید') #گذشته مجهول
# Out:
# ['دیده شدم', 'دیده شدی', 'دیده شد', 'دیده شدیم', 'دیده شدید', 'دیده شدند']

# %%
conj.past_progresive('دید')
# Out:
# ['داشتم می\u200cدیدم',
#  'داشتی می\u200cدیدی',
#  'داشت می\u200cدید',
#  'داشتیم می\u200cدیدیم',
#  'داشتید می\u200cدیدید',
#  'داشتند می\u200cدیدند']

# %%
conj.perfective_future('دید')
# Out:
# ['خواهم دید',
#  'خواهی دید',
#  'خواهد دید',
#  'خواهیم دید',
#  'خواهید دید',
#  'خواهند دید']

# %%
from lancedb.embeddings import WordEmbedding
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 from lancedb.embeddings import WordEmbedding
#
# ImportError: cannot import name 'WordEmbedding' from 'lancedb.embeddings' (C:\Users\f.zarei\AppData\Local\anaconda3\Lib\site-packages\lancedb\embeddings\__init__.py)

# %%
wordEmbedding = WordEmbedding(model_type = 'fasttext')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 wordEmbedding = WordEmbedding(model_type = 'fasttext')
#
# TypeError: WordEmbedding.__init__() missing 1 required positional argument: 'model'
